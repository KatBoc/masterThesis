# %%
from datetime import datetime
from pathlib import Path

import plotly.graph_objects as go
import plotly.express as px
from scripts.ETL.co2analytics import CO2Analytics
import pandas as pd

# %%
CO2Analytics = CO2Analytics(main_dir=Path('C:/Users/KatarzynaBocian(2399/Desktop/BDA/masterThesis/scripts'))
CO2Analytics.run()
print('finished transforming the data')
# Out:
# (108, 20)
# (10928, 36)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 CO2Analytics = CO2Analytics(main_dir=Path('C:/Users/KatarzynaBocian(2399/Desktop/BDA/masterThesis/scripts'))
# ----> 2 CO2Analytics.run()
#       3 print('finished transforming the data')
#
# File ~\Desktop\BDA\masterThesis\scripts\ETL\co2analytics.py:29, in CO2Analytics.run(self)
#      26 def run(self):
#      27     self.wroclaw_data, self.world_data = self._get_data()
#      28     self.transformed_wroclaw_data, self.transformed_world_data \
# ---> 29         = self._get_transformed_data()
#
# File ~\Desktop\BDA\masterThesis\scripts\ETL\co2analytics.py:46, in CO2Analytics._get_transformed_data(self)
#      44     self.transformed_wroclaw_data = transform_wroclaw_data(self.wroclaw_data)
#      45 if self.transformed_world_data is None:
# ...

# %%
raw = CO2Analytics.transformed_world_data
# raw.drop(columns=['total'], inplace=True)

# %%
raw.columns
# Out:
# Index(['Country', 'Source', 'Sector', 'Gas', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021'],
#       dtype='object')

# %%
raw
# Out:
#       Country         Source                 Sector      Gas       1990  \
# 0         AFG  Climate Watch   Total excluding LUCF  All GHG  11.627536
# 1         AFG  Climate Watch   Total including LUCF  All GHG   9.238795
# 2         AFG  Climate Watch                Energy   All GHG   2.280285
# 3         AFG  Climate Watch  Industrial Processes   All GHG   0.052709
# 4         AFG  Climate Watch           Agriculture   All GHG   8.065925
# ...       ...            ...                    ...      ...        ...
# 10923     ZWE  Climate Watch  Industrial Processes     F-Gas   0.067604
# 10924     ZWE  Climate Watch   Total including LUCF      CO2  26.937019
# 10925     ZWE  Climate Watch   Total including LUCF      CH4   9.695817
# 10926     ZWE  Climate Watch   Total including LUCF      N2O   5.937650
# 10927     ZWE  Climate Watch   Total including LUCF    F-Gas   0.067604
#
#             1991       1992       1993       1994       1995  ...       2012  \
# ...

# %%
df_melted = raw.melt(id_vars=['Country', 'Source', 'Sector', 'Gas'],
                     var_name='Year', value_name='Emissions')
df_melted
# Out:
#        Country         Source                 Sector      Gas  Year  Emissions
# 0          AFG  Climate Watch   Total excluding LUCF  All GHG  1990  11.627536
# 1          AFG  Climate Watch   Total including LUCF  All GHG  1990   9.238795
# 2          AFG  Climate Watch                Energy   All GHG  1990   2.280285
# 3          AFG  Climate Watch  Industrial Processes   All GHG  1990   0.052709
# 4          AFG  Climate Watch           Agriculture   All GHG  1990   8.065925
# ...        ...            ...                    ...      ...   ...        ...
# 349691     ZWE  Climate Watch  Industrial Processes     F-Gas  2021   0.976243
# 349692     ZWE  Climate Watch   Total including LUCF      CO2  2021  96.714439
# 349693     ZWE  Climate Watch   Total including LUCF      CH4  2021  12.428957
# 349694     ZWE  Climate Watch   Total including LUCF      N2O  2021   4.923862
# 349695     ZWE  Climate Watch   Total including LUCF    F-Gas  2021   0.976243
#
# ...

# %%
df_melted.drop('source')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_melted.drop('source')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
# ...
